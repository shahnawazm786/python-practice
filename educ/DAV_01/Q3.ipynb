# %%
import pandas as pd
import seaborn as sns

# %%
typ = ['Desktop', 'Laptop', 'Tablet', 'Desktop', 'Desktop', 'Desktop', 'Desktop', 'Desktop', 'Laptop', 'Laptop', 'Tablet', 'Tablet', 'Laptop', 'Laptop', 'Tablet', 'Laptop', 'Laptop', 'Tablet', 'Tablet', 'Desktop']
src = ['Poster 1', 'Poster 4', 'Poster 4', 'Email', 'Poster 4', 'Poster 2', 'Poster 1', 'Poster 3', 'Poster 4', 'Poster 4', 'Poster 3', 'Poster 3', 'Website', 'Poster 3', 'Poster 2', 'Poster 1', 'Website', 'Website', 'Poster 1', 'Poster 3']
df = pd.DataFrame({'Product Type': typ, 'Source': src})

# %%
print(df)
# Out:
#    Product Type    Source
# 0       Desktop  Poster 1
# 1        Laptop  Poster 4
# 2        Tablet  Poster 4
# 3       Desktop     Email
# 4       Desktop  Poster 4
# 5       Desktop  Poster 2
# 6       Desktop  Poster 1
# 7       Desktop  Poster 3
# 8        Laptop  Poster 4
# 9        Laptop  Poster 4
# 10       Tablet  Poster 3
# 11       Tablet  Poster 3
# 12       Laptop   Website
# 13       Laptop  Poster 3
# 14       Tablet  Poster 2
# 15       Laptop  Poster 1
# 16       Laptop   Website
# 17       Tablet   Website
# 18       Tablet  Poster 1
# 19      Desktop  Poster 3

# %%
sns.countplot(data=df,x='Source',hue='Source',
    palette='Set1',
    legend=False)
# Out:
# <Axes: xlabel='Source', ylabel='count'>

# %%
cp = sns.countplot(data=df,x='Source',palette='Set3',hue='Source')
