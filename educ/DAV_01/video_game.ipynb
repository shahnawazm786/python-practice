# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %%
# !gdown https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/021/299/original/final_vg1_-_final_vg_%281%29.csv?1670840166 -O final_vg.csv
# Out:
# Downloading...
# From: https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/021/299/original/final_vg1_-_final_vg_%281%29.csv?1670840166
# To: c:\desktop-folder\30Jun2025\scaler_25JuneBatch\python\python-project\educ\DAV_01\final_vg.csv
#
#   0%|          | 0.00/2.04M [00:00<?, ?B/s]
#  51%|█████▏    | 1.05M/2.04M [00:00<00:00, 7.39MB/s]
# 100%|██████████| 2.04M/2.04M [00:00<00:00, 6.56MB/s]
# 100%|██████████| 2.04M/2.04M [00:00<00:00, 6.67MB/s]

# %%
x=[0,1,2]
y=[3,5,9]
plt.plot(x,y)
plt.show()

# %%
protein=[4, 3, 4, 4, 2, 2, 2, 3, 2, 3, 1, 6, 1, 3, 1, 2, 2, 1, 1, 3, 3, 2, 2, 2, 2, 1, 3, 3, 3, 1, 2, 1, 3, 3, 3, 1, 3, 1, 2, 3, 2, 4, 2, 4, 4, 4, 3, 2, 2, 3, 3, 3, 3, 3, 1, 2, 4, 5, 3, 3, 2, 1, 2, 2, 3, 3, 2, 6, 2, 2, 3, 3, 2, 1, 3, 3, 2] 
data=pd.DataFrame(protein)
print(data)
protein_data=data.value_counts()
#print(protein_data.sort_values())
# Out:
#     0
# 0   4
# 1   3
# 2   4
# 3   4
# 4   2
# .. ..
# 72  2
# 73  1
# 74  3
# 75  3
# 76  2
#
# [77 rows x 1 columns]

# %%
fig=plt.figure()
plt.bar(height=protein_data.T.sort_values(ascending=True),x=[1,2,3,4,5,6],width=0.5,color=['green'])
#plt.bar(height=protein,x=[1,2,3,4,5,6],width=0.5,color=['green'])
plt.xlabel('Protein amount in grams')
plt.ylabel("Number of cereals")
#plt.Axes(fig,[10,10,10,10],label='Protein comparison')
plt.title('Protein comparison')
plt.show()

# %%
data=np.array(protein)

# %%
value,counts = np.unique(data,return_counts=True)
print(value)
print(counts)
# Out:
# [1 2 3 4 5 6]
# [13 25 28  8  1  2]

# %%
bars=plt.bar(x=value, height=counts,color='g')
plt.xlabel('Protein intake')
plt.ylabel('Protein comparision')
plt.title('Protein chart')
plt.show()

# %%
categories = ['Electronics', 'Clothing', 'Electronics', 'Electronics', 'Clothing', 'Clothing', 'Electronics', 'Electronics', 'Clothing', 'Electronics', 'Clothing', 'Clothing', 'Electronics', 'Clothing', 'Electronics', 'Electronics', 'Clothing', 'Clothing', 'Electronics', 'Electronics']   
sources = ['Social Media', 'Email', 'TV Advertisement', 'Social Media', 'Email', 'TV Advertisement', 'Social Media', 'Email', 'TV Advertisement', 'Social Media', 'Email', 'TV Advertisement', 'Social Media', 'Email', 'TV Advertisement', 'Social Media', 'Email', 'TV Advertisement', 'Social Media', 'Email']   
df = pd.DataFrame({'Category': categories, 'Marketing Source': sources})
print(df)
df_value_counts=df.value_counts()
print(df_value_counts)
# Out:
#        Category  Marketing Source
# 0   Electronics      Social Media
# 1      Clothing             Email
# 2   Electronics  TV Advertisement
# 3   Electronics      Social Media
# 4      Clothing             Email
# 5      Clothing  TV Advertisement
# 6   Electronics      Social Media
# 7   Electronics             Email
# 8      Clothing  TV Advertisement
# 9   Electronics      Social Media
# 10     Clothing             Email
# 11     Clothing  TV Advertisement
# 12  Electronics      Social Media
# 13     Clothing             Email
# 14  Electronics  TV Advertisement
# 15  Electronics      Social Media
# 16     Clothing             Email
# 17     Clothing  TV Advertisement
# 18  Electronics      Social Media
# 19  Electronics             Email
# Category     Marketing Source
# Electronics  Social Media        7
# Clothing     Email               5
#              TV Advertisement    4
# Electronics  Email               2
#              TV Advertisement    2
# Name: count, dtype: int64

# %%
#sns.countplot(data=df.value_counts())
source_order = ['Social Media', 'Email', 'TV Advertisement']

cp = sns.countplot(
    x='Marketing Source',
    hue='Category',
    data=df,
    order=source_order
)

cp.set_xlabel('Source')
# Out:
# Text(0.5, 0, 'Source')
