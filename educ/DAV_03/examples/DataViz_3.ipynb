# %% [markdown]
# ## Agenda
#
# - Boxplots
# - Bivariate Data Visualization
# - Continous-Continuous
#   - Line plot
#   - Styling and Labelling
#   - Scatter plot
# - Categorical-Categorical
#   - Dodged countplot
#   - Stacked countplot
# - Categorical-Continuous
#   - Boxplot
#
# - Subplots

# %%
# !gdown https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/021/299/original/final_vg1_-_final_vg_%281%29.csv?1670840166 -O vgsales.csv
# Out:
# Downloading...
# From: https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/021/299/original/final_vg1_-_final_vg_%281%29.csv?1670840166
# To: /content/vgsales.csv
# 100% 2.04M/2.04M [00:00<00:00, 148MB/s]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv('vgsales.csv')
data.head()
# Out:
#     Rank                               Name Platform    Year         Genre  \
# 0   2061                               1942      NES  1985.0       Shooter
# 1   9137       ¡Shin Chan Flipa en colores!       DS  2007.0      Platform
# 2  14279  .hack: Sekai no Mukou ni + Versus      PS3  2012.0        Action
# 3   8359         .hack//G.U. Vol.1//Rebirth      PS2  2006.0  Role-Playing
# 4   7109       .hack//G.U. Vol.2//Reminisce      PS2  2006.0  Role-Playing
#
#             Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0              Capcom  4.569217  3.033887  3.439352     1.991671     12.802935
# 1           505 Games  2.076955  1.493442  3.033887     0.394830      7.034163
# 2  Namco Bandai Games  1.145709  1.762339  1.493442     0.408693      4.982552
# 3  Namco Bandai Games  2.031986  1.389856  3.228043     0.394830      7.226880
# 4  Namco Bandai Games  2.792725  2.592054  1.440483     1.493442      8.363113

# %% [markdown]
# How can we understand popularity of video games year by year?

# %%
plt.hist(data["Year"],bins=30)
plt.show()

# %%
sns.histplot(data["Year"],bins=30,kde=True)
plt.show()

# %%
sns.kdeplot(data["Year"])
plt.show()

# %% [markdown]
# Boxplot

# %%
plt.figure(figsize=(8,6))
sns.boxplot(data["Global_Sales"])
plt.yticks(fontsize=12)
plt.ylabel('Global Sales (in million dollars)', fontsize=12)
plt.title('Global Sales of video games', fontsize=12)
plt.show()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Line Plot

# %% [markdown]
# ### To check the trend

# %% [markdown]
# Continous vs Continous

# %%
game_life = data.groupby(by = "Name").agg(min_year = ("Year", "min"),
                              max_year = ("Year", "max"))

game_life["range"] = game_life["max_year"] - game_life["min_year"]

game_life_sorted = game_life.sort_values(by = "range", ascending = False).head()
game_life_sorted.reset_index(inplace=True)

game_life_sorted
# Out:
#                                Name  min_year  max_year  range
# 0                        Ice Hockey    1980.0    2020.0   40.0
# 1                          Baseball    1980.0    2019.0   39.0
# 2                        Battlezone    1982.0    2006.0   24.0
# 3  Romance of the Three Kingdoms II    1991.0    2015.0   24.0
# 4                         Bomberman    1985.0    2008.0   23.0

# %%
game_life_sorted["Name"][0]
# Out:
# 'Ice Hockey'

# %%
ih=data[data["Name"]==game_life_sorted["Name"][0]]

# %%
ih
# Out:
#       Rank        Name Platform    Year   Genre   Publisher  NA_Sales  \
# 6073   639  Ice Hockey      NES  1988.0  Sports    Nintendo      0.44
# 6074  4027  Ice Hockey     2600  1980.0  Sports  Activision      0.39
# 6075  4149  Ice Hockey     2600  1991.0  Sports  Activision      0.61
# 6076  4149  Ice Hockey     2600  1992.0  Sports  Activision      0.65
# 6077  4149  Ice Hockey     SNES  1993.0  Sports  Activision      0.68
# 6078  4149  Ice Hockey     SNES  1994.0  Sports  Activision      0.75
# 6079  4149  Ice Hockey     SNES  1995.0  Sports  Activision      0.78
# 6080  4149  Ice Hockey     SNES  1996.0  Sports  Activision      0.76
# 6081  4149  Ice Hockey     SNES  1997.0  Sports  Activision      0.82
# 6082  4149  Ice Hockey     SNES  1998.0  Sports  Activision      0.88
# 6083  4149  Ice Hockey     SNES  1999.0  Sports  Activision      0.85
# 6084  4148  Ice Hockey     SNES  2000.0  Sports  Activision      0.84
# ...

# %%
ih[["Year","NA_Sales"]]
# Out:
#         Year  NA_Sales
# 6073  1988.0      0.44
# 6074  1980.0      0.39
# 6075  1991.0      0.61
# 6076  1992.0      0.65
# 6077  1993.0      0.68
# 6078  1994.0      0.75
# 6079  1995.0      0.78
# 6080  1996.0      0.76
# 6081  1997.0      0.82
# 6082  1998.0      0.88
# 6083  1999.0      0.85
# 6084  2000.0      0.84
# 6085  2001.0      0.87
# 6086  2002.0      0.90
# 6087  2003.0      0.70
# 6088  2004.0      0.60
# 6089  2005.0      0.63
# 6090  2006.0      0.57
# 6091  2007.0      0.58
# 6092  2008.0      0.49
# 6093  2009.0      0.40
# 6094  2010.0      0.43
# 6095  2011.0      0.42
# 6096  2012.0      0.40
# 6097  2013.0      0.41
# 6098  2014.0      0.45
# 6099  2015.0      0.35
# 6100  2016.0      0.38
# 6101  2017.0      0.30
# 6102  2018.0      0.20
# 6103  2019.0      0.19
# 6104  2020.0      0.14
# 6105  1990.0      0.60
# 6106  1981.0      0.40
# 6107  1982.0      0.52
# 6108  1983.0      0.58
# 6109  1984.0      0.60
# 6110  1986.0      0.48
# 6111  1987.0      0.45
# ...

# %%
plt.title("Ice Hockey Sales Trend")
sns.lineplot(x="Year",y="NA_Sales",data=ih,color="r")
plt.show()

# %%
def plot_trend(n):
  ih=data[data["Name"]==game_life_sorted["Name"][n]]
  plt.title(f'{game_life_sorted["Name"][n]}Sales Trend')
  sns.lineplot(x="Year",y="NA_Sales",data=ih,color="r")
  plt.show()
for i in range(5):
  plot_trend(n=i)

# %%
ih=data[data["Name"]==game_life_sorted["Name"][0]]
bb=data[data["Name"]==game_life_sorted["Name"][1]]
sns.lineplot(x='Year',y='NA_Sales',data=ih,label="Ice Hockey")
sns.lineplot(x='Year',y='NA_Sales',data=bb,label="Baseball")
plt.legend(loc="upper right",ncol=2,frameon=False)
plt.show()

# %%
# ih=data[data["Name"]==game_life_sorted["Name"][0]]
# bb=data[data["Name"]==game_life_sorted["Name"][1]]
# sns.lineplot(x='Year',y='NA_Sales',data=[ih,bb],label=["Ice Hockey","Baseball"])

# %% [markdown]
# Scatter Plot -> when to find linear relationship between two variables

# %% [markdown]
# ### Are Rank and Sales positively or negatively correlated

# %%
sns.lineplot(data=data,x="Rank",y="Global_Sales")
# Out:
# <Axes: xlabel='Rank', ylabel='Global_Sales'>

# %%
sns.scatterplot(data=data,x="Rank",y="Global_Sales")
# Out:
# <Axes: xlabel='Rank', ylabel='Global_Sales'>

# %% [markdown]
# Dodged Countplot/Side-by-side barchart--> when you are comparing categorical vs categorical

# %%
top3_pub=data["Publisher"].value_counts().index[:3]
top3_gen=data["Genre"].value_counts().index[:3]
top3_plat=data["Platform"].value_counts().index[:3]
top3_data=data.loc[(data["Publisher"].isin(top3_pub))& (data["Genre"].isin(top3_gen))& (data["Platform"].isin(top3_plat))]
top3_data.shape
# Out:
# (617, 11)

# %%
data.shape
# Out:
# (16652, 11)

# %%
data["Publisher"].value_counts().index
# Out:
# Index(['Electronic Arts', 'Activision', 'Namco Bandai Games', 'Ubisoft',
#        'Konami Digital Entertainment', 'Nintendo', 'THQ',
#        'Sony Computer Entertainment', 'Sega', 'Take-Two Interactive',
#        ...
#        'Ascaron Entertainment', 'TechnoSoft', 'Pow', 'Kamui', 'King Records',
#        'Intergrow', 'Takuyo', 'Origin Systems', 'Michaelsoft', 'MediaQuest'],
#       dtype='object', name='Publisher', length=578)

# %%
X = ['Electronic Arts', 'Activision', 'Namco Bandai Games', 'Ubisoft',
       'Konami Digital Entertainment', 'MediaQuest']

X[:3]
# Out:
# ['Electronic Arts', 'Activision', 'Namco Bandai Games']

# %% [markdown]
# How can we comparfe the top 3 platforms these publishers use?

# %%
plt.figure(figsize=(6,4))
sns.countplot(x='Publisher',data=top3_data)
plt.ylabel("Count of Games")
# Out:
# Text(0, 0.5, 'Count of Games')

# %% [markdown]
# Stacked Barchart

# %%
df_stacked_plot=pd.crosstab(index=top3_data["Publisher"],columns=top3_data["Genre"])

# %%
df_stacked_plot.plot(kind="bar",stacked=True)
# Out:
# <Axes: xlabel='Publisher'>

# %% [markdown]
# Cat vs Numerical --> Box plot

# %% [markdown]
# ### What is the distribution of sales for top3 publishers

# %%
# sns.boxplot(x='Publisher',y='Global_Sales',data=top3_data)
# plt.xticks(rotation=90,fontsize=12)
# plt.yticks(fontsize=12)
# plt.title("Sales for top3 Publisher")
# plt.show()

# %%
# from collections import Counter
# lst=[2,2,3,3,3]
# counts=Counter(lst)
# x=list(counts.keys())
# y=list(counts.values())
# plt.bar(x,y,color='g')

# %% [markdown]
# ## Agenda
#
# 1. Subplots
# 2. Multivariate Data Visualization
# 3. Joint plot
# 4. Pairplot
# 5. Correlation Heatmap

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Use subplots when you want to compare two charts side by side or one above another

# %%
fig=plt.figure(figsize=(10,10))
plt.subplot(2,3,1)
sns.scatterplot(x='NA_Sales',y='EU_Sales',data=top3_data)

plt.subplot(2,3,3)
sns.scatterplot(x='NA_Sales',y='EU_Sales',data=top3_data,color='red')

plt.subplot(2,3,3)
sns.scatterplot(x='NA_Sales',y='EU_Sales',data=top3_data,color='green')

plt.subplot(2,3,5)
sns.scatterplot(x='NA_Sales',y='EU_Sales',data=top3_data,color='orange')

fig.suptitle('Main Title')
# Out:
# Text(0.5, 0.98, 'Main Title')

# %%
fig = plt.figure(figsize=(7,7))

plt.subplot(2, 3, 1)
sns.scatterplot(x='NA_Sales', y='EU_Sales', data=top3_data)

plt.subplot(2, 3, 4)
sns.scatterplot(x='NA_Sales', y='JP_Sales', data=top3_data, color='red')

plt.subplot(2, 3, 6)
sns.scatterplot(x='NA_Sales', y='JP_Sales', data=top3_data, color='orange')

plt.subplot(2, 3, 2)
sns.scatterplot(x='NA_Sales', y='JP_Sales', data=top3_data, color='black')

plt.subplot(2, 3, 3)
sns.scatterplot(x='NA_Sales', y='JP_Sales', data=top3_data, color='blue')

plt.subplot(2, 3, 5)
sns.scatterplot(x='NA_Sales', y='JP_Sales', data=top3_data, color='pink')

plt.subplot(1, 3, 1)
sns.scatterplot(x='NA_Sales', y='JP_Sales', data=top3_data, color='magenta')

plt.subplot(2, 3, 1)
sns.scatterplot(x='NA_Sales', y='JP_Sales', data=top3_data, color='green')
# Out:
# <Axes: xlabel='NA_Sales', ylabel='EU_Sales'>

# %%
plt.subplot(2, 3, 1)
sns.scatterplot(x='NA_Sales', y='JP_Sales', data=top3_data, color='magenta')

plt.subplot(1, 3, 1)
sns.scatterplot(x='NA_Sales', y='JP_Sales', data=top3_data, color='cyan')

plt.subplot(2, 3, 1)
sns.scatterplot(x='NA_Sales', y='JP_Sales', data=top3_data, color='blue')
# Out:
# <Axes: xlabel='NA_Sales', ylabel='JP_Sales'>

# %%
fig = plt.figure(figsize=(7,7))

plt.subplot(2, 3, 1)
sns.scatterplot(x='NA_Sales', y='EU_Sales', data=top3_data)

plt.subplot(2, 3, 4)
sns.scatterplot(x='NA_Sales', y='JP_Sales', data=top3_data, color='red')

plt.subplot(1, 3, 2)
sns.scatterplot(x='NA_Sales', y='JP_Sales', data=top3_data, color='orange')

plt.subplot(2, 3, 2)
sns.scatterplot(x='NA_Sales', y='JP_Sales', data=top3_data, color='black')

plt.subplot(1, 3, 1)
sns.scatterplot(x='NA_Sales', y='JP_Sales', data=top3_data, color='blue')


fig.suptitle('Main title')
# Out:
# Text(0.5, 0.98, 'Main title')

# %% [markdown]
# Multivariate analysis Visualization

# %%
top3_data
# Out:
#         Rank                                               Name Platform  \
# 2      14279                  .hack: Sekai no Mukou ni + Versus      PS3
# 13      2742                                      [Prototype 2]      PS3
# 16      1604                                        [Prototype]      PS3
# 19      1741                             007: Quantum of Solace      PS3
# 21      4501                             007: Quantum of Solace      PS2
# ...      ...                                                ...      ...
# 16438  14938  Yes! Precure 5 Go Go Zenin Shu Go! Dream Festival       DS
# 16479  10979                              Young Justice: Legacy      PS3
# 16601  11802                         ZhuZhu Pets: Quest for Zhu       DS
# 16636   9196                           Zoobles! Spring to Life!       DS
# 16640   9816                                               Zubo       DS
#
#          Year   Genre           Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %% [markdown]
# NNC(Num-Num-Cat)
#
# #How is Sales between EU and NA differs in context with publishers?

# %%
sns.scatterplot(data=top3_data,x='NA_Sales',y="EU_Sales",hue="Publisher")
plt.show()

# %%
top3_data[(top3_data['NA_Sales']> 3)& (top3_data['EU_Sales']>3.5)]
# Out:
#        Rank                                               Name Platform  \
# 13     2742                                      [Prototype 2]      PS3
# 16     1604                                        [Prototype]      PS3
# 19     1741                             007: Quantum of Solace      PS3
# 67     1614                   2010 FIFA World Cup South Africa      PS3
# 71     2903                         2014 FIFA World Cup Brazil      PS3
# ...     ...                                                ...      ...
# 15078   669                          Tony Hawk's Underground 2      PS2
# 15234  1835  Transformers: The Game (XBox 360, PS2, PS3, Wi...      PS2
# 15286  2403                                   Triple Play 2002      PS2
# 15322   412                          True Crime: Streets of LA      PS2
# 16338  2753         X-Men Origins: Wolverine - Uncaged Edition      PS3
#
#          Year   Genre        Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %% [markdown]
# ## CCN --> (Cat - Cat - Num)

# %% [markdown]
# # How will you visualize the global sales for each publisher, but separated by genres?

# %%
sns.barplot(data=top3_data,x="Publisher",y="Global_Sales",hue="Genre")
# Out:
# <Axes: xlabel='Publisher', ylabel='Global_Sales'>

# %% [markdown]
# NNN (All three Numerical)
#
# # How does rank affect the correlation between NA and EU Sales?

# %%
sns.scatterplot(data = top3_data, x = "EU_Sales", y = "NA_Sales",size="Rank",sizes=(1,300))
# Out:
# <Axes: xlabel='EU_Sales', ylabel='NA_Sales'>

# %% [markdown]
# joint plot -> It is used when we want to have two distributions. It is used for NUM VS NUM

# %%
sns.jointplot(x="NA_Sales",y="EU_Sales",data=top3_data,kind="hist")

# %%
sns.pairplot(data=top3_data,vars=['NA_Sales','EU_Sales','JP_Sales'],hue="Genre")

# %%
num_df=top3_data.select_dtypes(include=['int64','float64'])

# %%
num_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 617 entries, 2 to 16640
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          617 non-null    int64
#  1   Year          611 non-null    float64
#  2   NA_Sales      617 non-null    float64
#  3   EU_Sales      617 non-null    float64
#  4   JP_Sales      617 non-null    float64
#  5   Other_Sales   617 non-null    float64
#  6   Global_Sales  617 non-null    float64
# dtypes: float64(6), int64(1)
# memory usage: 38.6 KB

# %%
# Correlation ranges from -1 to 1
# 1 --> +ve
# 0 --> no Correlation
# -1 --> -ve

# %%
num_df.corr()
# Out:
#                   Rank      Year  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Rank          1.000000  0.328705 -0.873726 -0.735711  0.115459    -0.857567
# Year          0.328705  1.000000 -0.354256 -0.178026  0.055864    -0.239876
# NA_Sales     -0.873726 -0.354256  1.000000  0.617483 -0.233315     0.794353
# EU_Sales     -0.735711 -0.178026  0.617483  1.000000 -0.208249     0.771105
# JP_Sales      0.115459  0.055864 -0.233315 -0.208249  1.000000    -0.355825
# Other_Sales  -0.857567 -0.239876  0.794353  0.771105 -0.355825     1.000000
# Global_Sales -0.911721 -0.280351  0.856300  0.864147 -0.014193     0.878816
#
#               Global_Sales
# Rank             -0.911721
# Year             -0.280351
# NA_Sales          0.856300
# EU_Sales          0.864147
# JP_Sales         -0.014193
# Other_Sales       0.878816
# Global_Sales      1.000000

# %%
sns.scatterplot(data=top3_data, x="NA_Sales", y="Rank")
# Out:
# <Axes: xlabel='NA_Sales', ylabel='Rank'>

# %%
sns.heatmap(data=num_df.corr(),annot=True,cmap="Blues")
# Out:
# <Axes: >
